# %%
# !uv run lm-eval --model hf \
    --model_args pretrained="google/gemma-2-2b-it",dtype=bfloat16,trust_remote_code=True \
    --tasks mmlu,wmdp \
    --log_samples \
    --output_path "eval/gemma-2b" \
    --batch_size=8 \
    --seed 42
# Out:
# 2025-06-02:11:15:29,874 INFO     [lm_eval.__main__:379] Selected Tasks: ['mmlu', 'wmdp']
# 2025-06-02:11:15:29,876 INFO     [lm_eval.evaluator:169] Setting random seed to 42 | Setting numpy seed to 42 | Setting torch manual seed to 42 | Setting fewshot manual seed to 42
# 2025-06-02:11:15:29,876 INFO     [lm_eval.evaluator:206] Initializing hf model, with arguments: {'pretrained': 'google/gemma-2-2b-it', 'dtype': 'bfloat16', 'trust_remote_code': True}
# 2025-06-02:11:15:29,958 INFO     [lm_eval.models.huggingface:136] Using device 'cuda'
# config.json: 100%|█████████████████████████████| 838/838 [00:00<00:00, 8.55MB/s]
# tokenizer_config.json: 100%|███████████████| 47.0k/47.0k [00:00<00:00, 99.8MB/s]
# tokenizer.model: 100%|██████████████████████| 4.24M/4.24M [00:00<00:00, 134MB/s]
# tokenizer.json: 100%|███████████████████████| 17.5M/17.5M [00:00<00:00, 254MB/s]
# special_tokens_map.json: 100%|█████████████████| 636/636 [00:00<00:00, 8.61MB/s]
# ...
